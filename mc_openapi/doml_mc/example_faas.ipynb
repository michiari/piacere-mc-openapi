# %%
from mc_openapi.doml_mc.intermediate_model.metamodel import parse_metamodel, parse_inverse_associations
import yaml
with open("../assets/doml_meta.yaml") as mmf:
    mmdoc = yaml.load(mmf, yaml.Loader)
mm = parse_metamodel(mmdoc)
inv_assoc = parse_inverse_associations(mmdoc)

# %%
import prettyprinter as pp
from prettyprinter.prettyprinter import IMPLICIT_MODULES
pp.install_extras(include=['dataclasses'])

# %%
IMPLICIT_MODULES.add('doml_mc.intermediate_model.metamodel')
pp.pprint(mm["application_SoftwareComponent"])
# Out:
# mc_openapi.doml_mc.intermediate_model.metamodel.DOMLClass(
#     name='application_SoftwareComponent',
#     superclass='application_ApplicationComponent',
#     attributes={
#         'isPersistent': mc_openapi.doml_mc.intermediate_model.metamodel.DOMLAttribute(
#             name='isPersistent',
#             type='Boolean',
#             multiplicity=('1', '1'),
#             default=False
#         ),
#         'licenseCost': mc_openapi.doml_mc.intermediate_model.metamodel.DOMLAttribute(
#             name='licenseCost',
#             type='String',
#             multiplicity=('0', '1'),
#             default=None
#         ),
#         'configFile': mc_openapi.doml_mc.intermediate_model.metamodel.DOMLAttribute(
#             name='configFile',
#             type='String',
#             multiplicity=('0', '1'),
#             default=None
#         )
#     },
#     associations={
#         'exposedInterfaces': mc_openapi.doml_mc.intermediate_model.metamodel.DOMLAssociation(
#             name='exposedInterfaces',
#             class_='application_SoftwareInterface',
#             multiplicity=('0', '*')
#         ),
#         'consumedInterfaces': mc_openapi.doml_mc.intermediate_model.metamodel.DOMLAssociation(
#             name='consumedInterfaces',
#             class_='application_SoftwareInterface',
#             multiplicity=('0', '*')
#         )
#     }
# )

# %% [markdown]
# ### Load the DOML document here:

# %%
from mc_openapi.doml_mc.xmi_parser.doml_model import parse_doml_model
doml_document_path = "/home/michele/Repositories/piacere/DOML-case-study/faas/doml/faas.domlx"
# doml_document_path = "../../tests/doml/nginx-openstack_v2_wrong.domlx"
with open(doml_document_path, "rb") as xmif:
    doc = xmif.read()

im = parse_doml_model(doc, mm)
print(im)
# Out:
# {'source_code': DOMLElement(name='source_code', class_='commons_SProperty', attributes={'commons_Property::key': 'source_code', 'commons_SProperty::value': 'path/lambda/function/image_resize.py'}, associations={}), 'storage_interface': DOMLElement(name='storage_interface', class_='application_SoftwareInterface', attributes={'commons_DOMLElement::name': 'storage_interface'}, associations={}), 'bucket_in': DOMLElement(name='bucket_in', class_='application_SoftwareInterface', attributes={'commons_DOMLElement::name': 'bucket_in'}, associations={}), 'bucket_out': DOMLElement(name='bucket_out', class_='application_SoftwareInterface', attributes={'commons_DOMLElement::name': 'bucket_out'}, associations={}), 'handle_image': DOMLElement(name='handle_image', class_='application_SoftwareInterface', attributes={'commons_DOMLElement::name': 'handle_image'}, associations={}), 'image_resize': DOMLElement(name='image_resize', class_='application_SoftwareComponent', attributes={'application_SoftwareComponent::isPersistent': False, 'commons_DOMLElement::name': 'image_resize'}, associations={'commons_DOMLElement::annotations': {'source_code'}, 'application_SoftwareComponent::consumedInterfaces': {'bucket_out', 'storage_interface', 'bucket_in'}, 'application_SoftwareComponent::exposedInterfaces': {'handle_image'}}), 's1': DOMLElement(name='s1', class_='application_SaaS', attributes={'commons_DOMLElement::name': 's1'}, associations={'application_SaaS::exposedInterfaces': {'storage_interface', 'bucket_in'}}), 's2': DOMLElement(name='s2', class_='application_SaaS', attributes={'commons_DOMLElement::name': 's2'}, associations={'application_SaaS::exposedInterfaces': {'bucket_out', 'storage_interface'}}), 'notification': DOMLElement(name='notification', class_='application_SoftwareComponent', attributes={'application_SoftwareComponent::isPersistent': False, 'commons_DOMLElement::name': 'notification'}, associations={'application_SoftwareComponent::consumedInterfaces': {'handle_image', 'bucket_in'}}), 'web': DOMLElement(name='web', class_='application_SoftwareComponent', attributes={'application_SoftwareComponent::isPersistent': False, 'commons_DOMLElement::name': 'web'}, associations={'commons_DOMLElement::annotations': {'source_code'}, 'application_SoftwareComponent::consumedInterfaces': {'bucket_out', 'storage_interface'}}), 'ImageResizeApp': DOMLElement(name='ImageResizeApp', class_='application_ApplicationLayer', attributes={'commons_DOMLElement::name': 'ImageResizeApp'}, associations={'application_ApplicationLayer::components': {'notification', 's2', 'web', 'image_resize', 's1'}}), 'st1': DOMLElement(name='st1', class_='infrastructure_Storage', attributes={'infrastructure_Storage::size': 0, 'commons_DOMLElement::name': 'st1'}, associations={}), 'st2': DOMLElement(name='st2', class_='infrastructure_Storage', attributes={'infrastructure_Storage::size': 0, 'commons_DOMLElement::name': 'st2'}, associations={}), 'icmp': DOMLElement(name='icmp', class_='infrastructure_Rule', attributes={'infrastructure_Rule::protocol': 'icmp', 'infrastructure_Rule::toPort': -1, 'infrastructure_Rule::fromPort': -1, 'commons_DOMLElement::name': 'icmp', 'infrastructure_Rule::kind': 'EGRESS'}, associations={}), 'http': DOMLElement(name='http', class_='infrastructure_Rule', attributes={'infrastructure_Rule::protocol': 'tcp', 'infrastructure_Rule::toPort': 80, 'infrastructure_Rule::fromPort': 80, 'commons_DOMLElement::name': 'http', 'infrastructure_Rule::kind': 'INGRESS'}, associations={}), 'https': DOMLElement(name='https', class_='infrastructure_Rule', attributes={'infrastructure_Rule::protocol': 'tcp', 'infrastructure_Rule::toPort': 443, 'infrastructure_Rule::fromPort': 443, 'commons_DOMLElement::name': 'https', 'infrastructure_Rule::kind': 'INGRESS'}, associations={}), 'ssh': DOMLElement(name='ssh', class_='infrastructure_Rule', attributes={'infrastructure_Rule::protocol': 'tcp', 'infrastructure_Rule::toPort': 22, 'infrastructure_Rule::fromPort': 22, 'commons_DOMLElement: ...
# Attribute cidr of multiplicity > 1 not supported yet.
# Attribute cidr of multiplicity > 1 not supported yet.
# Attribute cidr of multiplicity > 1 not supported yet.
# Attribute cidr of multiplicity > 1 not supported yet.

# %%
from mc_openapi.doml_mc.intermediate_model.doml_element import reciprocate_inverse_associations
reciprocate_inverse_associations(im, inv_assoc)

# %%
IMPLICIT_MODULES.add('doml_mc.intermediate_model.doml_element')
pp.pprint(im)
# Out:
# {
#     'source_code': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='source_code',
#         class_='commons_SProperty',
#         attributes={
#             'commons_Property::key': 'source_code',
#             'commons_SProperty::value': 'path/lambda/function/image_resize.py'
#         },
#         associations={}
#     ),
#     'storage_interface': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='storage_interface',
#         class_='application_SoftwareInterface',
#         attributes={'commons_DOMLElement::name': 'storage_interface'},
#         associations={}
#     ),
#     'bucket_in': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='bucket_in',
#         class_='application_SoftwareInterface',
#         attributes={'commons_DOMLElement::name': 'bucket_in'},
#         associations={}
#     ),
#     'bucket_out': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='bucket_out',
#         class_='application_SoftwareInterface',
#         attributes={'commons_DOMLElement::name': 'bucket_out'},
#         associations={}
#     ),
#     'handle_image': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='handle_image',
#         class_='application_SoftwareInterface',
#         attributes={'commons_DOMLElement::name': 'handle_image'},
#         associations={}
#     ),
#     'image_resize': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='image_resize',
#         class_='application_SoftwareComponent',
#         attributes={
#             'application_SoftwareComponent::isPersistent': False,
#             'commons_DOMLElement::name': 'image_resize'
#         },
#         associations={
#             'commons_DOMLElement::annotations': {'source_code'},
#             'application_SoftwareComponent::consumedInterfaces': {
#                 'bucket_out',
#                 'storage_interface',
#                 'bucket_in'
#             },
#             'application_SoftwareComponent::exposedInterfaces': {
#                 'handle_image'
#             }
#         }
#     ),
#     's1': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='s1',
#         class_='application_SaaS',
#         attributes={'commons_DOMLElement::name': 's1'},
#         associations={
#             'application_SaaS::exposedInterfaces': {
#                 'storage_interface',
#                 'bucket_in'
#             }
#         }
#     ),
#     's2': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='s2',
#         class_='application_SaaS',
#         attributes={'commons_DOMLElement::name': 's2'},
#         associations={
#             'application_SaaS::exposedInterfaces': {
#                 'bucket_out',
#                 'storage_interface'
#             }
#         }
#     ),
#     'notification': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='notification',
#         class_='application_SoftwareComponent',
#         attributes={
#             'application_SoftwareComponent::isPersistent': False,
#             'commons_DOMLElement::name': 'notification'
#         },
#         associations={
#             'application_SoftwareComponent::consumedInterfaces': {
#                 'handle_image',
#                 'bucket_in'
#             }
#         }
#     ),
#     'web': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='web',
#         class_='application_SoftwareComponent',
#         attributes={
#             'application_SoftwareComponent::isPersistent': False,
#             'commons_DOMLElement::name': 'web'
#         },
#         associations={
#             'commons_DOMLElement::annotations': {'source_code'},
#             'application_SoftwareComponent::consumedInterfaces': {
#                 'bucket_out',
#                 'storage_interface'
#             }
#         }
#     ),
#     'ImageResizeApp': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='ImageResizeApp',
#         class_='application_ApplicationLayer',
#         attributes={'commons_DOMLElement::name': 'ImageResizeApp'},
#         associations={
#             'application_ApplicationLayer::components': {
#                 'notification',
#                 's2',
#                 'web',
#                 'image_resize',
#                 's1'
#             }
#         }
#     ),
#     'st1': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='st1',
#         class_='infrastructure_Storage',
#         attributes={
#             'infrastructure_Storage::size': 0,
#             'commons_DOMLElement::name': 'st1'
#         },
#         associations={}
#     ),
#     'st2': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='st2',
#         class_='infrastructure_Storage',
#         attributes={
#             'infrastructure_Storage::size': 0,
#             'commons_DOMLElement::name': 'st2'
#         },
#         associations={}
#     ),
#     'icmp': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='icmp',
#         class_='infrastructure_Rule',
#         attributes={
#             'infrastructure_Rule::protocol': 'icmp',
#             'infrastructure_Rule::toPort': -1,
#             'infrastructure_Rule::fromPort': -1,
#             'commons_DOMLElement::name': 'icmp',
#             'infrastructure_Rule::kind': 'EGRESS'
#         },
#         associations={}
#     ),
#     'http': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='http',
#         class_='infrastructure_Rule',
#         attributes={
#             'infrastructure_Rule::protocol': 'tcp',
#             'infrastructure_Rule::toPort': 80,
#             'infrastructure_Rule::fromPort': 80,
#             'commons_DOMLElement::name': 'http',
#             'infrastructure_Rule::kind': 'INGRESS'
#         },
#         associations={}
#     ),
#     'https': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='https',
#         class_='infrastructure_Rule',
#         attributes={
#             'infrastructure_Rule::protocol': 'tcp',
#             'infrastructure_Rule::toPort': 443,
#             'infrastructure_Rule::fromPort': 443,
#             'commons_DOMLElement::name': 'https',
#             'infrastructure_Rule::kind': 'INGRESS'
#         },
#         associations={}
#     ),
#     'ssh': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='ssh',
#         class_='infrastructure_Rule',
#         attributes={
#             'infrastructure_Rule::protocol': 'tcp',
#             'infrastructure_Rule::toPort': 22,
#             'infrastructure_Rule::fromPort': 22,
#             'commons_DOMLElement::name': 'ssh',
#             'infrastructure_Rule::kind': 'INGRESS'
#         },
#         associations={}
#     ),
#     'ssh_key': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='ssh_key',
#         class_='infrastructure_KeyPair',
#         attributes={
#             'infrastructure_KeyPair::algorithm': 'RSA',
#             'infrastructure_KeyPair::keyfile': '/tmp/ssh_key_file',
#             'infrastructure_KeyPair::bits': 4096,
#             'infrastructure_KeyPair::user': 'ec2-user',
#             'commons_DOMLElement::name': 'ssh_key'
#         },
#         associations={}
#     ),
#     '__generated_name__0': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='__generated_name__0',
#         class_='infrastructure_Location',
#         attributes={
#             'commons_DOMLElement::name': '__generated_name__0',
#             'infrastructure_Location::region': 'eu-central-1'
#         },
#         associations={}
#     ),
#     'v_img': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='v_img',
#         class_='infrastructure_VMImage',
#         attributes={
#             'infrastructure_ComputingNodeGenerator::uri': 'ami-xxxxxxxxxxxxxxxxx',
#             'infrastructure_ComputingNodeGenerator::kind': 'IMAGE',
#             'commons_DOMLElement::name': 'v_img'
#         },
#         associations={'infrastructure_VMImage::generatedVMs': {'vm1'}}
#     ),
#     'vm1': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='vm1',
#         class_='infrastructure_VirtualMachine',
#         attributes={'commons_DOMLElement::name': 'vm1'},
#         associations={
#             'infrastructure_ComputingNode::credentials': {'ssh_key'},
#             'infrastructure_ComputingNode::location': {'__generated_name__0'},
#             'infrastructure_ComputingNode::group': {'sg'},
#             'infrastructure_VirtualMachine::generatedFrom': {'v_img'},
#             'infrastructure_ComputingNode::ifaces': {'i1'}
#         }
#     ),
#     'sg': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='sg',
#         class_='infrastructure_SecurityGroup',
#         attributes={'commons_DOMLElement::name': 'sg'},
#         associations={
#             'infrastructure_SecurityGroup::rules': {
#                 'https',
#                 'icmp',
#                 'http',
#                 'ssh'
#             },
#             'infrastructure_ComputingGroup::groupedNodes': {'vm1'},
#             'infrastructure_SecurityGroup::ifaces': {'i1'}
#         }
#     ),
#     'i1': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='i1',
#         class_='infrastructure_NetworkInterface',
#         attributes={
#             'infrastructure_NetworkInterface::endPoint': 167772161,
#             'commons_DOMLElement::name': 'i1'
#         },
#         associations={
#             'infrastructure_NetworkInterface::belongsTo': {'vpc'},
#             'infrastructure_NetworkInterface::associated': {'sg'}
#         }
#     ),
#     'vpc_subnet': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='vpc_subnet',
#         class_='infrastructure_Subnet',
#         attributes={
#             'infrastructure_Network::address_lb': 167772160,
#             'infrastructure_Network::address_ub': 167772415,
#             'infrastructure_Network::protocol': 'tcp/ip',
#             'commons_DOMLElement::name': 'vpc_subnet'
#         },
#         associations={}
#     ),
#     'vpc': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='vpc',
#         class_='infrastructure_VPC',
#         attributes={
#             'infrastructure_Network::address_lb': 167772160,
#             'infrastructure_Network::address_ub': 167772415,
#             'infrastructure_Network::protocol': 'tcp/ip',
#             'commons_DOMLElement::name': 'vpc'
#         },
#         associations={
#             'infrastructure_Network::connectedIfaces': {'i1'},
#             'infrastructure_VPC::subnets': {'vpc_subnet'}
#         }
#     ),
#     'f': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='f',
#         class_='infrastructure_FunctionAsAService',
#         attributes={'commons_DOMLElement::name': 'f'},
#         associations={}
#     ),
#     'c': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='c',
#         class_='infrastructure_Container',
#         attributes={'commons_DOMLElement::name': 'c'},
#         associations={
#             'infrastructure_Container::generatedFrom': {'c_img'},
#             'infrastructure_Container::hosts': {'vm1'}
#         }
#     ),
#     'c_img': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='c_img',
#         class_='infrastructure_ContainerImage',
#         attributes={
#             'infrastructure_ComputingNodeGenerator::uri': 'web-app:0.1.0',
#             'infrastructure_ComputingNodeGenerator::kind': 'IMAGE',
#             'commons_DOMLElement::name': 'c_img'
#         },
#         associations={
#             'infrastructure_ContainerImage::generatedContainers': {'c'}
#         }
#     ),
#     'infra': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='infra',
#         class_='infrastructure_InfrastructureLayer',
#         attributes={'commons_DOMLElement::name': 'infra'},
#         associations={
#             'infrastructure_InfrastructureLayer::storages': {'st1', 'st2'},
#             'infrastructure_InfrastructureLayer::networks': {'vpc'},
#             'infrastructure_InfrastructureLayer::groups': {'sg'},
#             'infrastructure_InfrastructureLayer::faas': {'f'},
#             'infrastructure_InfrastructureLayer::generators': {
#                 'c_img',
#                 'v_img'
#             },
#             'infrastructure_InfrastructureLayer::credentials': {'ssh_key'},
#             'infrastructure_InfrastructureLayer::nodes': {'vm1', 'c'}
#         }
#     ),
#     '__generated_name__1': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='__generated_name__1',
#         class_='commons_Deployment',
#         attributes={},
#         associations={
#             'commons_Deployment::node': {'f'},
#             'commons_Deployment::component': {'image_resize'}
#         }
#     ),
#     '__generated_name__2': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='__generated_name__2',
#         class_='commons_Deployment',
#         attributes={},
#         associations={
#             'commons_Deployment::node': {'c'},
#             'commons_Deployment::component': {'web'}
#         }
#     ),
#     '__generated_name__3': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='__generated_name__3',
#         class_='commons_Deployment',
#         attributes={},
#         associations={
#             'commons_Deployment::node': {'st1'},
#             'commons_Deployment::component': {'s1'}
#         }
#     ),
#     '__generated_name__4': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='__generated_name__4',
#         class_='commons_Deployment',
#         attributes={},
#         associations={
#             'commons_Deployment::node': {'st2'},
#             'commons_Deployment::component': {'s2'}
#         }
#     ),
#     'config1': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='config1',
#         class_='commons_Configuration',
#         attributes={'commons_DOMLElement::name': 'config1'},
#         associations={
#             'commons_Configuration::deployments': {
#                 '__generated_name__2',
#                 '__generated_name__3',
#                 '__generated_name__1',
#                 '__generated_name__4'
#             }
#         }
#     ),
#     'instance_type': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='instance_type',
#         class_='commons_SProperty',
#         attributes={
#             'commons_Property::key': 'instance_type',
#             'commons_SProperty::value': 't2.micro'
#         },
#         associations={}
#     ),
#     'ssh_key_name': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='ssh_key_name',
#         class_='commons_SProperty',
#         attributes={
#             'commons_Property::key': 'ssh_key_name',
#             'commons_SProperty::value': 'demo-key'
#         },
#         associations={}
#     ),
#     'ec2_role_name': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='ec2_role_name',
#         class_='commons_SProperty',
#         attributes={
#             'commons_Property::key': 'ec2_role_name',
#             'commons_SProperty::value': 'demo-ec2-role'
#         },
#         associations={}
#     ),
#     'concrete_vm': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='concrete_vm',
#         class_='concrete_VirtualMachine',
#         attributes={'commons_DOMLElement::name': 'concrete_vm'},
#         associations={
#             'concrete_VirtualMachine::maps': {'vm1'},
#             'commons_DOMLElement::annotations': {
#                 'ec2_role_name',
#                 'instance_type',
#                 'ssh_key_name'
#             }
#         }
#     ),
#     'lambda_role_name': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='lambda_role_name',
#         class_='commons_SProperty',
#         attributes={
#             'commons_Property::key': 'lambda_role_name',
#             'commons_SProperty::value': 'DemoLambdaRole'
#         },
#         associations={}
#     ),
#     'lambda_runtime': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='lambda_runtime',
#         class_='commons_SProperty',
#         attributes={
#             'commons_Property::key': 'lambda_runtime',
#             'commons_SProperty::value': 'python3.8'
#         },
#         associations={}
#     ),
#     'lambda_handler': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='lambda_handler',
#         class_='commons_SProperty',
#         attributes={
#             'commons_Property::key': 'lambda_handler',
#             'commons_SProperty::value': 'image_resize.lambda_handler'
#         },
#         associations={}
#     ),
#     'lambda_timeout': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='lambda_timeout',
#         class_='commons_IProperty',
#         attributes={
#             'commons_Property::key': 'lambda_timeout',
#             'commons_IProperty::value': 5
#         },
#         associations={}
#     ),
#     'lambda_memory': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='lambda_memory',
#         class_='commons_IProperty',
#         attributes={
#             'commons_Property::key': 'lambda_memory',
#             'commons_IProperty::value': 128
#         },
#         associations={}
#     ),
#     'concrete_f': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='concrete_f',
#         class_='concrete_FunctionAsAService',
#         attributes={'commons_DOMLElement::name': 'concrete_f'},
#         associations={
#             'commons_DOMLElement::annotations': {
#                 'lambda_runtime',
#                 'lambda_timeout',
#                 'lambda_role_name',
#                 'lambda_memory',
#                 'lambda_handler'
#             },
#             'concrete_FunctionAsAService::maps': {'f'}
#         }
#     ),
#     'concrete_net': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='concrete_net',
#         class_='concrete_Network',
#         attributes={'commons_DOMLElement::name': 'concrete_net'},
#         associations={'concrete_Network::maps': {'vpc'}}
#     ),
#     'bucket_name': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='bucket_name',
#         class_='commons_SProperty',
#         attributes={
#             'commons_Property::key': 'bucket_name',
#             'commons_SProperty::value': 'bucket_in'
#         },
#         associations={}
#     ),
#     's3_bucket_in': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='s3_bucket_in',
#         class_='concrete_Storage',
#         attributes={'commons_DOMLElement::name': 's3_bucket_in'},
#         associations={
#             'commons_DOMLElement::annotations': {'bucket_name'},
#             'concrete_Storage::maps': {'st1'}
#         }
#     ),
#     's3_bucket_out': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='s3_bucket_out',
#         class_='concrete_Storage',
#         attributes={'commons_DOMLElement::name': 's3_bucket_out'},
#         associations={
#             'commons_DOMLElement::annotations': {'bucket_name'},
#             'concrete_Storage::maps': {'st2'}
#         }
#     ),
#     'aws': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='aws',
#         class_='concrete_RuntimeProvider',
#         attributes={'commons_DOMLElement::name': 'aws'},
#         associations={
#             'concrete_RuntimeProvider::vms': {'concrete_vm'},
#             'concrete_RuntimeProvider::faas': {'concrete_f'},
#             'concrete_RuntimeProvider::networks': {'concrete_net'},
#             'concrete_RuntimeProvider::storages': {
#                 's3_bucket_out',
#                 's3_bucket_in'
#             }
#         }
#     ),
#     'con_infra': mc_openapi.doml_mc.intermediate_model.doml_element.DOMLElement(
#         name='con_infra',
#         class_='concrete_ConcreteInfrastructure',
#         attributes={'commons_DOMLElement::name': 'con_infra'},
#         associations={'concrete_ConcreteInfrastructure::providers': {'aws'}}
#     )
# }

# %%
unbound_elems_n = 0
unbound_elems = [f"unbound{i}" for i in range(unbound_elems_n)]

# %%
from z3 import Solver

from mc_openapi.doml_mc.z3encoding.metamodel_encoding import (
    def_association_rel_and_assert_constraints,
    def_attribute_rel_and_assert_constraints,
    mk_association_sort_dict,
    mk_attribute_sort_dict,
    mk_class_sort_dict
)
from mc_openapi.doml_mc.z3encoding.im_encoding import (
    assert_im_associations_q,
    assert_im_attributes,
    def_elem_class_f_and_assert_classes,
    mk_elem_sort_dict,
    mk_stringsym_sort_dict
)
from mc_openapi.doml_mc.z3encoding.utils import mk_adata_sort

solver = Solver()

class_sort, class_ = mk_class_sort_dict(mm)
assoc_sort, assoc = mk_association_sort_dict(mm)
attr_sort, attr = mk_attribute_sort_dict(mm)
elem_sort, elem = mk_elem_sort_dict(im, unbound_elems)
ss_sort, ss = mk_stringsym_sort_dict(im, mm)
AData = mk_adata_sort(ss_sort)
elem_class_f = def_elem_class_f_and_assert_classes(
    im,
    solver,
    elem_sort,
    elem,
    class_sort,
    class_
)
attr_rel = def_attribute_rel_and_assert_constraints(
    mm,
    solver,
    attr_sort,
    attr,
    class_,
    elem_class_f,
    elem_sort,
    AData,
    ss
)
assert_im_attributes(
    attr_rel,
    solver,
    im,
    mm,
    elem,
    attr_sort,
    attr,
    AData,
    ss
)
assoc_rel = def_association_rel_and_assert_constraints(
    mm,
    solver,
    assoc_sort,
    assoc,
    class_,
    elem_class_f,
    elem_sort,
    inv_assoc
)
assert_im_associations_q(
    assoc_rel,
    solver,
    {k: v for k, v in im.items() if k not in unbound_elems},
    elem,
    assoc_sort,
    assoc,
)

# %%
# solver.push()

# %% [markdown]
# ### Metamodel statistics

# %%
from mc_openapi.doml_mc.intermediate_model.metamodel import get_subclasses_dict

print("Number of classes:", len(mm))
print(
    "Number of tuples in the subclass relation:",
    sum(len(s) for s in get_subclasses_dict(mm).values())
)
n_attrs = sum(len(c.attributes) for c in mm.values())
print("Number of attributes:", n_attrs)
print("Number of attribute assertions:", 3 * n_attrs)
n_assocs = sum(len(c.associations) for c in mm.values())
print("Number of associations:", n_assocs)
print("Number of associations assertions:", 3 * n_assocs + len(inv_assoc))
# Out:
# Number of classes: 51
# Number of tuples in the subclass relation: 133
# Number of attributes: 47
# Number of attribute assertions: 141
# Number of associations: 56
# Number of associations assertions: 174

# %% [markdown]
# ### DOML model statistics

# %%
n_elems = len(im)
print("Number of elements:", n_elems)
n_attrs_im = sum(len(e.attributes) for e in im.values())
print("Number of attributes (IM):", n_attrs_im)
n_assocs_im = sum(len(a) for e in im.values() for a in e.associations.values())
print("Number of associations (IM):", n_assocs_im)
print("Number of string symbols:", len(ss))
print("Number of IM attribute assertions:", n_elems)
print("Number of IM association assertions:", n_elems ** 2)
# Out:
# Number of elements: 50
# Number of attributes (IM): 93
# Number of associations (IM): 81
# Number of string symbols: 65
# Number of IM attribute assertions: 50
# Number of IM association assertions: 2500

# %%
# solver.check()

# %%
# solver.unsat_core()

# %%
# solver.statistics()

# %%
from z3 import Consts, ForAll, Exists, Implies, And, Or

# %%
# All VMs have a network interface.
vm, iface = Consts("vm iface", elem_sort)
vmIfaceAssertion = ForAll(
    [vm],
    Implies(
        elem_class_f(vm) == class_["infrastructure_VirtualMachine"],
        Exists(
            [iface],
            assoc_rel(vm, assoc["infrastructure_ComputingNode::ifaces"], iface),
        )
    )
)
solver.assert_and_track(vmIfaceAssertion, "vm_iface")

# %%
# All software packages can see the interfaces they need through a common network.
asc_consumer, asc_exposer, siface, net, net_iface, cn, vm, deployment, dc = Consts(
    "asc_consumer asc_exposer siface net net_iface cn vm deployment dc", elem_sort
)
assn = ForAll(
    [asc_consumer, asc_exposer, siface],
    Implies(
        And(
            assoc_rel(asc_consumer, assoc["application_SoftwareComponent::exposedInterfaces"], siface),
            assoc_rel(asc_exposer, assoc["application_SoftwareComponent::consumedInterfaces"], siface),
        ),
        Exists(
            [net],
            And(
                Or(
                    Exists(
                        [cn, deployment, net_iface],
                        And(  # asc_consumer is deployed on a component with an interface in network n
                            assoc_rel(deployment, assoc["commons_Deployment::component"], asc_consumer),
                            assoc_rel(deployment, assoc["commons_Deployment::node"], cn),
                            assoc_rel(cn, assoc["infrastructure_ComputingNode::ifaces"], net_iface),
                            assoc_rel(net_iface, assoc["infrastructure_NetworkInterface::belongsTo"], net),
                        ),
                    ),
                    Exists(  # asc_consumer is deployed on a container hosting a VM with an interface in network n
                        [cn, deployment, vm, net_iface],
                        And(
                            assoc_rel(deployment, assoc["commons_Deployment::component"], asc_consumer),
                            assoc_rel(deployment, assoc["commons_Deployment::node"], cn),
                            assoc_rel(cn, assoc["infrastructure_Container::hosts"], vm),
                            assoc_rel(vm, assoc["infrastructure_ComputingNode::ifaces"], net_iface),
                            assoc_rel(net_iface, assoc["infrastructure_NetworkInterface::belongsTo"], net),
                        ),
                    ),
                ),
                Or(
                    Exists(
                        [cn, deployment, net_iface],
                        And(  # asc_exposer is deployed on a component with an interface in network n
                            assoc_rel(deployment, assoc["commons_Deployment::component"], asc_exposer),
                            assoc_rel(deployment, assoc["commons_Deployment::node"], cn),
                            assoc_rel(cn, assoc["infrastructure_ComputingNode::ifaces"], net_iface),
                            assoc_rel(net_iface, assoc["infrastructure_NetworkInterface::belongsTo"], net),
                        ),
                    ),
                    Exists(  # asc_exposer is deployed on a container hosting a VM with an interface in network n
                        [cn, deployment, vm, net_iface],
                        And(
                            assoc_rel(deployment, assoc["commons_Deployment::component"], asc_exposer),
                            assoc_rel(deployment, assoc["commons_Deployment::node"], cn),
                            assoc_rel(cn, assoc["infrastructure_Container::hosts"], vm),
                            assoc_rel(vm, assoc["infrastructure_ComputingNode::ifaces"], net_iface),
                            assoc_rel(net_iface, assoc["infrastructure_NetworkInterface::belongsTo"], net),
                        ),
                    ),
                ),
            ),
        ),
    ),
)
solver.assert_and_track(assn, "software_package_iface_net")

# %%
# SoftwareComponents have a source_code property
softwareComponent, prop = Consts("softwareComponent prop", elem_sort)
nginxSourceCode = ForAll(
    [softwareComponent],
    Implies(
        And(
            elem_class_f(softwareComponent) == class_["application_SoftwareComponent"],
            # attr_rel(softwareComponent, attr["commons_DOMLElement::name"], AData.ss(ss["web"]))
        ),
        Exists(
            [prop],
            And(
                elem_class_f(prop) == class_["commons_SProperty"],
                attr_rel(prop, attr["commons_Property::key"], AData.ss(ss["source_code"])),
                assoc_rel(softwareComponent, assoc["commons_DOMLElement::annotations"], prop)
            )
        )
    )
)
solver.assert_and_track(nginxSourceCode, "SoftwareComponent_source_code")

# %%
# There are no duplicated interfaces
def any_iface(elem, iface):
    ifaces_assocs = [
        "infrastructure_ComputingNode::ifaces",
        "infrastructure_Storage::ifaces",
        "infrastructure_FunctionAsAService::ifaces"
    ]
    return Or(*(assoc_rel(elem, assoc[assoc_name], iface) for assoc_name in ifaces_assocs))
e1, e2, ni = Consts("e1 e2 i", elem_sort)
assn = ForAll([e1, e2, ni],
    Implies(
        And(
            any_iface(e1, ni),
            any_iface(e2, ni)
        ),
        e1 == e2
    )
)
solver.assert_and_track(assn, "iface_uniq")

# %%
# All SoftwareComponents have been deployed somewhere
sc, deployment, ielem = Consts("sc deployment ielem", elem_sort)
assn = ForAll(
    [sc],
    Implies(
        elem_class_f(sc) == class_["application_SoftwareComponent"],
        Exists(
            [deployment, ielem],
            And(
                assoc_rel(deployment, assoc["commons_Deployment::component"], sc),
                assoc_rel(deployment, assoc["commons_Deployment::node"], ielem)
            )
        )
    )
)
solver.assert_and_track(assn, "all_SoftwareComponents_deployed")

# %%
# All abstract infrastructure elements are mapped to an element in the active concretization
def checkOneClass(ielem, concr, provider, celem, ielemClass, providerAssoc, celemAssoc):
    return Implies(
                elem_class_f(ielem) == class_[ielemClass],
                Exists(
                    [provider, celem],
                    And(
                        assoc_rel(concr, assoc["concrete_ConcreteInfrastructure::providers"], provider),
                        assoc_rel(provider, assoc[providerAssoc], celem),
                        assoc_rel(celem, assoc[celemAssoc], ielem)
                    )
                )
            )

ielem, concr, provider, celem = Consts("ielem, concr, provider, celem", elem_sort)
assn = Exists(
    [concr],
    And(
        elem_class_f(concr) == class_["concrete_ConcreteInfrastructure"],
        ForAll(
            [ielem],
            And(
                checkOneClass(
                    ielem, concr, provider, celem,
                    "infrastructure_VirtualMachine",
                    "concrete_RuntimeProvider::vms",
                    "concrete_VirtualMachine::maps"
                ),
                checkOneClass(
                    ielem, concr, provider, celem,
                    "infrastructure_Network",
                    "concrete_RuntimeProvider::networks",
                    "concrete_Network::maps"
                ),
                checkOneClass(
                    ielem, concr, provider, celem,
                    "infrastructure_Storage",
                    "concrete_RuntimeProvider::storages",
                    "concrete_Storage::maps"
                ),
                checkOneClass(
                    ielem, concr, provider, celem,
                    "infrastructure_FunctionAsAService",
                    "concrete_RuntimeProvider::faas",
                    "concrete_FunctionAsAService::maps"
                ),
            )
        )
    )
)
solver.assert_and_track(assn, "all_infrastructure_elements_deployed")

# %%
# The "web" component has access to the Internet through https
web, deployment, ielem1, ielem2, iface, sg, rule = Consts("web deployment ielem1 ielem2 iface sg rule", elem_sort)
assn = ForAll(
    [web],
    Implies(
        attr_rel(web, attr["commons_DOMLElement::name"], AData.ss(ss["web"])),
        Exists(  # web is deployed on a container hosting a VM with an interface in network n
            [deployment, ielem1, ielem2, iface, rule],
            And(
                assoc_rel(deployment, assoc["commons_Deployment::component"], web),
                assoc_rel(deployment, assoc["commons_Deployment::node"], ielem1),
                assoc_rel(ielem1, assoc["infrastructure_Container::hosts"], ielem2),
                assoc_rel(ielem2, assoc["infrastructure_ComputingNode::ifaces"], iface),
                assoc_rel(iface, assoc["infrastructure_NetworkInterface::associated"], sg),
                assoc_rel(sg, assoc["infrastructure_SecurityGroup::rules"], rule),
                attr_rel(rule, attr["infrastructure_Rule::fromPort"], AData.int(443)),
                attr_rel(rule, attr["infrastructure_Rule::toPort"], AData.int(443)),
                attr_rel(rule, attr["infrastructure_Rule::kind"], AData.ss(ss["INGRESS"]))
            ),
        )
    )
)
solver.assert_and_track(assn, "web_has_https")

# %%
solver.check()
# Out:
# sat

# %%
solver.unsat_core()
# Out:
# [elem_class source_code commons_SProperty,
#  elem_class storage_interface application_SoftwareInterface,
#  elem_class bucket_in application_SoftwareInterface,
#  elem_class bucket_out application_SoftwareInterface,
#  elem_class handle_image application_SoftwareInterface,
#  elem_class image_resize application_SoftwareComponent,
#  elem_class s1 application_SaaS,
#  elem_class s2 application_SaaS,
#  elem_class notification application_SoftwareComponent,
#  elem_class web application_SoftwareComponent,
#  elem_class ImageResizeApp application_ApplicationLayer,
#  elem_class vpc_subnet infrastructure_Subnet,
#  elem_class vpc infrastructure_VPC,
#  elem_class i1 infrastructure_NetworkInterface,
#  elem_class __generated_name__0 infrastructure_Location,
#  elem_class v_img infrastructure_VMImage,
#  elem_class ssh_key infrastructure_KeyPair,
#  elem_class vm1 infrastructure_VirtualMachine,
#  elem_class icmp infrastructure_Rule,
#  elem_class http infrastructure_Rule,
#  elem_class https infrastructure_Rule,
#  elem_class ssh infrastructure_Rule,
#  elem_class sg infrastructure_SecurityGroup,
#  elem_class f infrastructure_FunctionAsAService,
#  elem_class c infrastructure_Container,
#  elem_class c_img infrastructure_ContainerImage,
#  elem_class st1 infrastructure_Storage,
#  elem_class st2 infrastructure_Storage,
#  elem_class infra infrastructure_InfrastructureLayer,
#  elem_class lambda_role_name commons_SProperty,
#  elem_class lambda_runtime commons_SProperty,
#  elem_class lambda_handler commons_SProperty,
#  elem_class lambda_timeout commons_IProperty,
#  elem_class lambda_memory commons_IProperty,
#  elem_class concrete_f concrete_FunctionAsAService,
#  elem_class concrete_net concrete_Network,
#  elem_class bucket_name commons_SProperty,
#  elem_class s3_bucket_in concrete_Storage,
#  elem_class s3_bucket_out concrete_Storage,
#  elem_class instance_type commons_SProperty,
#  elem_class ssh_key_name commons_SProperty,
#  elem_class ec2_role_name commons_SProperty,
#  elem_class concrete_vm concrete_VirtualMachine,
#  elem_class aws concrete_RuntimeProvider,
#  elem_class con_infra concrete_ConcreteInfrastructure,
#  association_st_classes commons_Deployment::source,
#  association_st_classes commons_Deployment::target,
#  associations image_resize handle_image,
#  associations notification handle_image,
#  software_package_iface_net]

# %%
solver.statistics().memory
# Out:
# 66.31

# %%
m = solver.model()
print(m)
# Out:
# [attribute_st_types infrastructure_Rule::toPort = True,
#  associations sg out_all = True,
#  associations i1 http = True,
#  associations ag http = True,
#  associations vm_flavor con_infra = True,
#  associations openstack concrete_vm_image = True,
#  attribute_mult_ub commons_BProperty::value = True,
#  associations v_img name = True,
#  attribute_mult_lb infrastructure_Rule::kind = True,
#  associations vm1 name = True,
#  attribute_st_types commons_DOMLElement::name = True,
#  association_mult_ub concrete_FunctionAsAService::maps = True,
#  associations concrete_vm vm_key_name = True,
#  associations app openstack = True,
#  association_inverse infrastructure_Container::generatedFrom infrastructure_ContainerImage::generatedContainers = True,
#  associations app concrete_vm = True,
#  associations out_all v_img = True,
#  association_mult_ub infrastructure_Container::generatedFrom = True,
#  association_st_classes infrastructure_FunctionAsAService::ifaces = True,
#  associations net1 ssh = True,
#  associations con_infra con_infra = True,
#  associations https concrete_vm = True,
#  associations sg ssh = True,
#  associations vm_name v_img = True,
#  associations ssh_key openstack = True,
#  association_st_classes infrastructure_Storage::ifaces = True,
#  associations openstack vm_flavor = True,
#  associations nginx nginx = True,
#  attribute_st_types infrastructure_Rule::addressRanges = True,
#  associations vm_flavor v_img = True,
#  associations v_img ag = True,
#  association_st_classes concrete_ComputingGroup::maps = True,
#  attribute_mult_lb infrastructure_Rule::protocol = True,
#  associations vm1 ag = True,
#  associations ag vm_flavor = True,
#  attribute_mult_ub infrastructure_KeyPair::bits = True,
#  associations nginx openstack = True,
#  associations app sg = True,
#  association_mult_ub commons_Property::reference = True,
#  associations nginx infra = True,
#  associations concrete_net vm_key_name = True,
#  associations https concrete_vm_image = True,
#  associations v_img vm_name = True,
#  associations concrete_net openstack = True,
#  attribute_st_types commons_Property::key = True,
#  association_mult_ub commons_Deployment::source = True,
#  associations concrete_vm_image v_img = True,
#  associations source_code https = True,
#  associations vm_name vm_flavor = True,
#  elem_class concrete_vm concrete_VirtualMachine = True,
#  attribute_mult_ub application_SoftwareComponent::isPersistent = True,
#  associations https ssh = True,
#  associations https vm1 = True,
#  associations ag net1 = True,
#  associations http source_code = True,
#  association_mult_ub concrete_VirtualMachine::maps = True,
#  association_st_classes commons_Deployment::target = True,
#  associations net1 con_infra = True,
#  attribute_st_types concrete_ConcreteElement::configurationScript = True,
#  association_mult_ub infrastructure_VirtualMachine::generatedFrom = True,
#  associations http vm_key_name = True,
#  associations vm_name infra = True,
#  associations ag source_code = True,
#  associations vm_key_name net1 = True,
#  attribute_st_types infrastructure_ComputingNode::cost = True,
#  association_mult_ub infrastructure_NetworkInterface::belongsTo = True,
#  associations infra ssh = True,
#  associations out_all concrete_net = True,
#  associations sg source_code = True,
#  association_inverse infrastructure_ComputingGroup::groupedNodes infrastructure_ComputingNode::group = True,
#  associations concrete_vm_image infra = True,
#  associations source_code out_all = True,
#  associations ssh sg = True,
#  associations ssh name = True,
#  associations http ag = True,
#  associations out_all concrete_vm_image = True,
#  association_st_classes concrete_VMImage::maps = True,
#  associations vm1 openstack = True,
#  associations v_img source_code = True,
#  elem_class ssh_key infrastructure_KeyPair = True,
#  associations vm_flavor app = True,
#  associations concrete_vm net1 = True,
#  associations vm_name http = True,
#  associations app out_all = True,
#  associations vm_key_name name = True,
#  attribute_st_types infrastructure_KeyPair::keyfile = True,
#  associations v_img nginx = True,
#  associations v_img concrete_net = True,
#  attribute_st_types infrastructure_KeyPair::user = True,
#  associations http concrete_vm = True,
#  association_mult_ub commons_Deployment::target = True,
#  associations ssh app = True,
#  associations ssh vm_name = True,
#  associations source_code ssh_key = True,
#  associations vm1 ssh_key = True,
#  associations nginx vm_name = True,
#  associations http https = True,
#  attribute_values vm_key_name = True,
#  associations ssh_key concrete_net = True,
#  associations infra i1 = True,
#  associations https https = True,
#  attribute_st_types infrastructure_Rule::fromPort = True,
#  associations nginx vm_key_name = True,
#  associations app nginx = True,
#  associations v_img v_img = True,
#  associations sg http = True,
#  associations con_infra nginx = True,
#  associations con_infra https = True,
#  elem_class name commons_SProperty = True,
#  attribute_mult_ub infrastructure_AutoScalingGroup::max = True,
#  association_mult_lb concrete_ComputingGroup::maps = True,
#  attribute_mult_ub application_SoftwareComponent::configFile = True,
#  associations net1 ag = True,
#  association_mult_lb commons_Deployment::target = True,
#  attribute_values con_infra = True,
#  association_mult_ub concrete_ContainerImage::maps = True,
#  associations vm_flavor vm_name = True,
#  associations v_img concrete_vm = True,
#  associations concrete_vm ssh = True,
#  associations concrete_vm v_img = True,
#  attribute_st_types application_SoftwareComponent::configFile = True,
#  attribute_mult_ub infrastructure_AutoScalingGroup::loadBalancer = True,
#  associations vm1 v_img = True,
#  association_st_classes infrastructure_InfrastructureLayer::generators = True,
#  attribute_mult_ub infrastructure_ComputingNode::cost = True,
#  attribute_st_types application_SoftwareComponent::licenseCost = True,
#  associations ssh vm_key_name = True,
#  associations vm1 app = True,
#  associations concrete_vm_image name = True,
#  ...]

# %%
from itertools import product
for (e1n, e1), a, (e2n, e2) in product(elem.items(), assoc.values(), elem.items()):
    if (e1n in unbound_elems or e2n in unbound_elems) and m.eval(assoc_rel(e1, a, e2)):
        print(e1, a, e2)
